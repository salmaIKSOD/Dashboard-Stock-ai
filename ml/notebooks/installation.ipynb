# %%
import sys
# !{sys.executable} -m pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Using cached sqlalchemy-2.0.50-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Using cached greenlet-3.5.1-cp313-cp313-win_amd64.whl.metadata (3.9 kB)
# Collecting typing-extensions>=4.6.0 (from sqlalchemy)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Using cached sqlalchemy-2.0.50-cp313-cp313-win_amd64.whl (2.1 MB)
# Using cached greenlet-3.5.1-cp313-cp313-win_amd64.whl (238 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing-extensions, greenlet, sqlalchemy
# Successfully installed greenlet-3.5.1 sqlalchemy-2.0.50 typing-extensions-4.15.0
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip uninstall -y tabulate
# Out:
# Found existing installation: tabulate 0.10.0
# Uninstalling tabulate-0.10.0:
#   Successfully uninstalled tabulate-0.10.0

# %%
# !pip install rich
# Out:
# Collecting rich
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting markdown-it-py>=2.2.0 (from rich)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from rich) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: mdurl, markdown-it-py, rich
# Successfully installed markdown-it-py-4.2.0 mdurl-0.1.2 rich-15.0.0
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip uninstall pyarrow

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.8.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: narwhals>=1.15.1 in d:\python313\lib\site-packages (from plotly) (2.22.1)
# Requirement already satisfied: packaging in c:\users\dell\appdata\roaming\python\python313\site-packages (from plotly) (25.0)
# Downloading plotly-6.8.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 1.1 MB/s eta 0:00:09
#    --- ------------------------------------ 0.8/9.9 MB 1.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.0/9.9 MB 1.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.3/9.9 MB 1.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.3/9.9 MB 1.1 MB/s eta 0:00:09
#    ------ --------------------------------- 1.6/9.9 MB 1.1 MB/s eta 0:00:08
#    ------- -------------------------------- 1.8/9.9 MB 1.0 MB/s eta 0:00:09
#    -------- ------------------------------- 2.1/9.9 MB 1.0 MB/s eta 0:00:08
#    -------- ------------------------------- 2.1/9.9 MB 1.0 MB/s eta 0:00:08
#    --------- ------------------------------ 2.4/9.9 MB 1.0 MB/s eta 0:00:08
#    ---------- ----------------------------- 2.6/9.9 MB 973.1 kB/s eta 0:00:08
#    ----------- ---------------------------- 2.9/9.9 MB 1.0 MB/s eta 0:00:07
#    ------------ --------------------------- 3.1/9.9 MB 1.0 MB/s eta 0:00:07
#    ------------ --------------------------- 3.1/9.9 MB 1.0 MB/s eta 0:00:07
#    ------------- -------------------------- 3.4/9.9 MB 1.0 MB/s eta 0:00:07
#    -------------- ------------------------- 3.7/9.9 MB 1.0 MB/s eta 0:00:06
#    --------------- ------------------------ 3.9/9.9 MB 1.0 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.2/9.9 MB 1.0 MB/s eta 0:00:06
#    ------------------ --------------------- 4.5/9.9 MB 1.0 MB/s eta 0:00:06
#    ------------------- -------------------- 4.7/9.9 MB 1.1 MB/s eta 0:00:05
#    ------------------- -------------------- 4.7/9.9 MB 1.1 MB/s eta 0:00:05
#    -------------------- ------------------- 5.0/9.9 MB 1.1 MB/s eta 0:00:05
#    --------------------- ------------------ 5.2/9.9 MB 1.1 MB/s eta 0:00:05
#    ---------------------- ----------------- 5.5/9.9 MB 1.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 5.8/9.9 MB 1.1 MB/s eta 0:00:04
#    ------------------------ --------------- 6.0/9.9 MB 1.1 MB/s eta 0:00:04
#    ------------------------- -------------- 6.3/9.9 MB 1.1 MB/s eta 0:00:04
#    ------------------------- -------------- 6.3/9.9 MB 1.1 MB/s eta 0:00:04
#    -------------------------- ------------- 6.6/9.9 MB 1.1 MB/s eta 0:00:04
#    --------------------------- ------------ 6.8/9.9 MB 1.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.1/9.9 MB 1.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 7.3/9.9 MB 1.1 MB/s eta 0:00:03
#    ------------------------------ --------- 7.6/9.9 MB 1.1 MB/s eta 0:00:03
#    ------------------------------ --------- 7.6/9.9 MB 1.1 MB/s eta 0:00:03
#    ------------------------------- -------- 7.9/9.9 MB 1.1 MB/s eta 0:00:02
#    -------------------------------- ------- 8.1/9.9 MB 1.1 MB/s eta 0:00:02
#    --------------------------------- ------ 8.4/9.9 MB 1.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.7/9.9 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------ --- 8.9/9.9 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 1.1 MB/s eta 0:00:00
# Installing collected packages: plotly
# Successfully installed plotly-6.8.0
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\dell\appdata\roaming\python\python313\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from ipywidgets) (9.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\dell\appdata\roaming\python\python313\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\dell\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\dell\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\dell\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\dell\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\dell\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\dell\appdata\roaming\python\python313\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: wcwidth in c:\users\dell\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\dell\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Using cached widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
# Successfully installed ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 widgetsnbextension-4.0.15
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install statsforecast
